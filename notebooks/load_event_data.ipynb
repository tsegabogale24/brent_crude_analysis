# %%
import pandas as pd

events = [
    {"event_name": "Black Monday Crash", "start_date": "1987-10-19", "category": "Economic Shock", "source": "https://www.investopedia.com/terms/b/blackmonday.asp"},
    {"event_name": "Gulf War – Iraq Invades Kuwait", "start_date": "1990-08-02", "category": "Geopolitical", "source": "https://www.eia.gov/todayinenergy/detail.php?id=7270"},
    {"event_name": "Asian Financial Crisis", "start_date": "1997-07-02", "category": "Economic Shock", "source": "https://www.imf.org/external/np/exr/ib/2000/062300.htm"},
    {"event_name": "NATO Bombing of Yugoslavia", "start_date": "1999-03-24", "category": "Geopolitical", "source": "https://www.britannica.com/event/Kosovo-conflict"},
    {"event_name": "9/11 Terrorist Attacks", "start_date": "2001-09-11", "category": "Geopolitical", "source": "https://www.eia.gov/todayinenergy/detail.php?id=4650"},
    {"event_name": "Iraq War Begins", "start_date": "2003-03-20", "category": "Geopolitical", "source": "https://www.cnbc.com/id/100000000"},
    {"event_name": "Hurricane Katrina", "start_date": "2005-08-29", "category": "Natural Disaster", "source": "https://www.eia.gov/todayinenergy/detail.php?id=3230"},
    {"event_name": "2008 Oil Price Peak", "start_date": "2008-07-03", "category": "Economic Shock", "source": "https://www.theguardian.com/business/2008/jul/03/oil.economy"},
    {"event_name": "2008 Global Financial Crisis", "start_date": "2008-09-15", "category": "Economic Shock", "source": "https://www.ft.com/content/d8e6b8b0-832a-11dd-a7d5-000077b07658"},
    {"event_name": "Arab Spring Begins", "start_date": "2010-12-17", "category": "Geopolitical", "source": "https://www.bbc.com/news/world-12482315"},
    {"event_name": "Libyan Civil War", "start_date": "2011-02-17", "category": "Geopolitical", "source": "https://www.reuters.com/article/libya-crisis-oil-idUSLDE72T2L420110330"},
    {"event_name": "2014–2016 Oil Price Collapse", "start_date": "2014-06-01", "category": "Market/OPEC", "source": "https://www.bloomberg.com/news/articles/2016-01-20/oil-prices-2014-2016"},
    {"event_name": "Reimposition of Iran Sanctions", "start_date": "2018-11-05", "category": "Sanctions", "source": "https://www.state.gov/reimposition-of-u-s-sanctions-on-the-islamic-republic-of-iran/"},
    {"event_name": "COVID-19 Pandemic", "start_date": "2020-03-11", "category": "Economic Shock", "source": "https://www.who.int/news/item/27-04-2020-who-timeline---covid-19"},
    {"event_name": "Russia-Ukraine War Begins", "start_date": "2022-02-24", "category": "Geopolitical", "source": "https://www.reuters.com/world/europe/russia-launches-invasion-ukraine-2022-02-24/"}
]

df = pd.DataFrame(events)
df.to_csv("../data/raw/event_data.csv", index=False)

# %% [markdown]
# Assumptions and Limitations
# - Events collected are assumed to be accurate and significant.
# - The model does not prove causality — only identifies correlation.
# - There may be confounding variables (e.g., other economic shocks).

# %% [markdown]
#  Communication Strategy
# - Jupyter Notebook with inline visuals for analysts
# - Executive summary in PDF format for management
# - Interactive Power BI dashboard for business users
